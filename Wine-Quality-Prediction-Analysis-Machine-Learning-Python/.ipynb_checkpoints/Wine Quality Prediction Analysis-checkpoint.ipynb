# %%
# import pandas
import pandas as pd

# import numpy
import numpy as np

# import seaborn
import seaborn as sb

# Reading the dataset
import matplotlib.pyplot as plt

# Reading the dataset
df = pd.read_csv('D:\DataSciencePortfolio\Datasets\winedata.csv', sep=',')

# Testing the datset
print(df.head())
print(df.info())
print(df.describe())

# %%
df1 = df

# %%
#cleaning columns name

df1.rename(columns={'fixed.acidity': 'fixedAcidity', 
                   'volatile.acidity':'volatileAcidity', 
                   'citric.acid': 'citricAcid',
                   'free.sulfur.dioxide': 'freeSulfurDioxide',
                  'total.sulfur.dioxide': 'totalSulfurDioxide',
                  'rt.sulfur.dioxide': 'rtSulfurDioxide'}, inplace=True)

# %%
display (df1)
# Out:
#       fixedAcidity  volatileAcidity  citricAcid  residual.sugar  chlorides  \
# 0              7.5             0.33        0.32            11.1      0.036
# 1              6.3             0.27        0.29            12.2      0.044
# 2              7.0             0.30        0.51            13.6      0.050
# 3              7.4             0.38        0.27             7.5      0.041
# 4              8.1             0.12        0.38             0.9      0.034
# ...            ...              ...         ...             ...        ...
# 2032           8.1             0.34        0.28             7.5      0.040
# 2033           7.4             0.19        0.31            14.5      0.045
# 2034           6.7             0.36        0.26             7.9      0.034
# 2035           7.7             0.28        0.35            15.3      0.056
# 2036           5.7             0.22        0.28             1.3      0.027
#
#       freeSulfurDioxide  totalSulfurDioxide  density    pH  sulphates  \
# 0                  25.0               119.0  0.99620  3.15       0.34
# 1                  59.0               196.0  0.99782  3.14       0.40
# 2                  40.0               168.0  0.99760  3.07       0.52
# 3                  24.0               160.0  0.99535  3.17       0.43
# 4                  36.0                86.0  0.99026  2.80       0.55
# ...                 ...                 ...      ...   ...        ...
# 2032               70.0               230.0  0.99558  3.14       0.55
# 2033               39.0               193.0  0.99860  3.10       0.50
# 2034               39.0               123.0  0.99119  2.99       0.30
# 2035               31.0               117.0  0.99980  3.27       0.50
# 2036               26.0               101.0  0.98948  3.35       0.38
#
#       alcohol  quality  rtSulfurDioxide
# 0        10.5        6         5.000000
# 1         8.8        6         7.681146
# 2         9.6        7         6.324555
# 3        10.0        5         4.898979
# 4        12.0        6         6.000000
# ...       ...      ...              ...
# 2032      9.8        6         8.366600
# 2033      9.2        6         6.244998
# 2034     12.2        7         6.244998
# 2035      9.6        5         5.567764
# 2036     12.5        7         5.099020
#
# [2037 rows x 13 columns]

# %%
#adding two digits of ID as decimal points ID=20215041 for fixedAcidity
df1 = df1.assign(fixedAcidity=df1.fixedAcidity+0.41)

display (df1)
# Out:
#       fixedAcidity  volatileAcidity  citricAcid  residual.sugar  chlorides  \
# 0             7.91             0.33        0.32            11.1      0.036
# 1             6.71             0.27        0.29            12.2      0.044
# 2             7.41             0.30        0.51            13.6      0.050
# 3             7.81             0.38        0.27             7.5      0.041
# 4             8.51             0.12        0.38             0.9      0.034
# ...            ...              ...         ...             ...        ...
# 2032          8.51             0.34        0.28             7.5      0.040
# 2033          7.81             0.19        0.31            14.5      0.045
# 2034          7.11             0.36        0.26             7.9      0.034
# 2035          8.11             0.28        0.35            15.3      0.056
# 2036          6.11             0.22        0.28             1.3      0.027
#
#       freeSulfurDioxide  totalSulfurDioxide  density    pH  sulphates  \
# 0                  25.0               119.0  0.99620  3.15       0.34
# 1                  59.0               196.0  0.99782  3.14       0.40
# 2                  40.0               168.0  0.99760  3.07       0.52
# 3                  24.0               160.0  0.99535  3.17       0.43
# 4                  36.0                86.0  0.99026  2.80       0.55
# ...                 ...                 ...      ...   ...        ...
# 2032               70.0               230.0  0.99558  3.14       0.55
# 2033               39.0               193.0  0.99860  3.10       0.50
# 2034               39.0               123.0  0.99119  2.99       0.30
# 2035               31.0               117.0  0.99980  3.27       0.50
# 2036               26.0               101.0  0.98948  3.35       0.38
#
#       alcohol  quality  rtSulfurDioxide
# 0        10.5        6         5.000000
# 1         8.8        6         7.681146
# 2         9.6        7         6.324555
# 3        10.0        5         4.898979
# 4        12.0        6         6.000000
# ...       ...      ...              ...
# 2032      9.8        6         8.366600
# 2033      9.2        6         6.244998
# 2034     12.2        7         6.244998
# 2035      9.6        5         5.567764
# 2036     12.5        7         5.099020
#
# [2037 rows x 13 columns]

# %%
#adding two digits of ID as decimal points ID=20215041

df1 = df1.assign(volatileAcidity=df1.volatileAcidity + 0.41)
df1 = df1.assign(citricAcid=df1.citricAcid + 0.41)
df1 = df1.assign(chlorides=df1.chlorides + 0.41)
df1 = df1.assign(freeSulfurDioxide=df1.freeSulfurDioxide + 0.41)
df1 = df1.assign(totalSulfurDioxide=df1.totalSulfurDioxide + 0.41)
df1 = df1.assign(density=df1.density + 0.41)
df1 = df1.assign(sulphates=df1.sulphates + 0.41)
df1 = df1.assign(alcohol=df1.alcohol + 0.41)

display (df2)
# Out:
#       fixedAcidity  volatileAcidity  citricAcid  residual.sugar  chlorides  \
# 0            7.910             0.33        0.32            11.1      0.036
# 1            6.710             0.27        0.29            12.2      0.044
# 2            7.410             0.30        0.51            13.6      0.050
# 3            7.810             0.38        0.27             7.5      0.041
# 4            8.510             0.12        0.38             0.9      0.034
# ...            ...              ...         ...             ...        ...
# 2038         0.069            11.00        2.30             0.0      0.600
# 2039         0.069            10.00        2.30             0.0      0.530
# 2040         0.069            11.00        2.30             0.0      0.600
# 2041         0.069            10.00        2.30             0.0      0.530
# 2042         0.069            11.00        2.30             0.0      0.600
#
#       freeSulfurDioxide  totalSulfurDioxide  density    pH  sulphates  \
# 0                  25.0               119.0  0.99620  3.15       0.34
# 1                  59.0               196.0  0.99782  3.14       0.40
# 2                  40.0               168.0  0.99760  3.07       0.52
# 3                  24.0               160.0  0.99535  3.17       0.43
# 4                  36.0                86.0  0.99026  2.80       0.55
# ...                 ...                 ...      ...   ...        ...
# 2038                6.6                65.3  4.20000  1.00     290.00
# 2039                6.5                65.2  4.01000  1.00     290.00
# 2040                6.6                65.3  4.20000  1.00     290.00
# 2041                6.5                65.2  4.01000  1.00     290.00
# 2042                6.6                65.3  4.20000  1.00     290.00
#
#       alcohol  quality  rtSulfurDioxide
# 0       10.91      6.0         5.000000
# 1        9.21      6.0         7.681146
# 2       10.01      7.0         6.324555
# 3       10.41      5.0         4.898979
# 4       12.41      6.0         6.000000
# ...       ...      ...              ...
# 2038    15.00    395.0         4.900000
# 2039    15.00    395.0         4.900000
# 2040    15.00    395.0         4.900000
# 2041    15.00    395.0         4.900000
# 2042    15.00    395.0         4.900000
#
# [2043 rows x 13 columns]

# %%
details = df1

#finding missing values using isnull() function
# Count total NaN at each column in DataFrame

print(" \nCount total NaN at each column in a DataFrame : \n\n",
      details.isnull().sum())
# Out:
#
# Count total NaN at each column in a DataFrame :
#
#  fixedAcidity          0
# volatileAcidity       0
# citricAcid            0
# residual.sugar        0
# chlorides             0
# freeSulfurDioxide     0
# totalSulfurDioxide    0
# density               0
# pH                    0
# sulphates             0
# alcohol               0
# quality               0
# rtSulfurDioxide       0
# dtype: int64

# %%
# List of data series
datarowsSeries = [pd.Series([0.069,10,2.3,0,0.53,6.5,65.2,4.01,1,290,15,395,4.9], index=df1.columns ), 
                  pd.Series([0.069,11,2.3,0,0.6,6.6,65.3,4.2,1,290,15,395,4.9], index=df1.columns ) ]

# Passing the list of data series to the append() to add multiple rows
df1 = df1.append(datarowsSeries , ignore_index=True)

# %%
display (df1)
# Out:
#       fixedAcidity  volatileAcidity  citricAcid  residual.sugar  chlorides  \
# 0            7.910             0.74        0.73            11.1      0.446
# 1            6.710             0.68        0.70            12.2      0.454
# 2            7.410             0.71        0.92            13.6      0.460
# 3            7.810             0.79        0.68             7.5      0.451
# 4            8.510             0.53        0.79             0.9      0.444
# ...            ...              ...         ...             ...        ...
# 2036         6.110             0.63        0.69             1.3      0.437
# 2037         0.069            10.00        2.30             0.0      0.530
# 2038         0.069            11.00        2.30             0.0      0.600
# 2039         0.069            10.00        2.30             0.0      0.530
# 2040         0.069            11.00        2.30             0.0      0.600
#
#       freeSulfurDioxide  totalSulfurDioxide  density    pH  sulphates  \
# 0                 25.41              119.41  1.40620  3.15       0.75
# 1                 59.41              196.41  1.40782  3.14       0.81
# 2                 40.41              168.41  1.40760  3.07       0.93
# 3                 24.41              160.41  1.40535  3.17       0.84
# 4                 36.41               86.41  1.40026  2.80       0.96
# ...                 ...                 ...      ...   ...        ...
# 2036              26.41              101.41  1.39948  3.35       0.79
# 2037               6.50               65.20  4.01000  1.00     290.00
# 2038               6.60               65.30  4.20000  1.00     290.00
# 2039               6.50               65.20  4.01000  1.00     290.00
# 2040               6.60               65.30  4.20000  1.00     290.00
#
#       alcohol  quality  rtSulfurDioxide
# 0       10.91      6.0         5.000000
# 1        9.21      6.0         7.681146
# 2       10.01      7.0         6.324555
# 3       10.41      5.0         4.898979
# 4       12.41      6.0         6.000000
# ...       ...      ...              ...
# 2036    12.91      7.0         5.099020
# 2037    15.00    395.0         4.900000
# 2038    15.00    395.0         4.900000
# 2039    15.00    395.0         4.900000
# 2040    15.00    395.0         4.900000
#
# [2041 rows x 13 columns]

# %%
# removing extra values

df1 = df1.drop(index=[2039,2038])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-e3cd3de781ff> in <module>
# ----> 1 df1 = df1.drop(index=[2039,2038])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: '[2039 2038] not found in axis'

# %%
display (df1)

# %%
df1.hist(bins=25,figsize=(10,10))
# display histogram
plt.show()

# %%
# creating box plots

def plot_boxplot(df1, ft):
    df1.boxplot(column=[ft])
    plt.grid(False)
    plt.show()

# %%
# Out:
#       fixedAcidity  volatileAcidity  citricAcid  residual.sugar  chlorides  \
# 0              7.5             0.33        0.32            11.1      0.036
# 1              6.3             0.27        0.29            12.2      0.044
# 2              7.0             0.30        0.51            13.6      0.050
# 3              7.4             0.38        0.27             7.5      0.041
# 4              8.1             0.12        0.38             0.9      0.034
# ...            ...              ...         ...             ...        ...
# 2032           8.1             0.34        0.28             7.5      0.040
# 2033           7.4             0.19        0.31            14.5      0.045
# 2034           6.7             0.36        0.26             7.9      0.034
# 2035           7.7             0.28        0.35            15.3      0.056
# 2036           5.7             0.22        0.28             1.3      0.027
#
#       freeSulfurDioxide  totalSulfurDioxide  density    pH  sulphates  \
# 0                  25.0               119.0  0.99620  3.15       0.34
# 1                  59.0               196.0  0.99782  3.14       0.40
# 2                  40.0               168.0  0.99760  3.07       0.52
# 3                  24.0               160.0  0.99535  3.17       0.43
# 4                  36.0                86.0  0.99026  2.80       0.55
# ...                 ...                 ...      ...   ...        ...
# 2032               70.0               230.0  0.99558  3.14       0.55
# 2033               39.0               193.0  0.99860  3.10       0.50
# 2034               39.0               123.0  0.99119  2.99       0.30
# 2035               31.0               117.0  0.99980  3.27       0.50
# 2036               26.0               101.0  0.98948  3.35       0.38
#
#       alcohol  quality  rtSulfurDioxide
# 0        10.5        6         5.000000
# 1         8.8        6         7.681146
# 2         9.6        7         6.324555
# 3        10.0        5         4.898979
# 4        12.0        6         6.000000
# ...       ...      ...              ...
# 2032      9.8        6         8.366600
# 2033      9.2        6         6.244998
# 2034     12.2        7         6.244998
# 2035      9.6        5         5.567764
# 2036     12.5        7         5.099020
#
# [2037 rows x 13 columns]

# %%
print(df1.head(20))
# Out:
#     fixedAcidity  volatileAcidity  citricAcid  residual.sugar  chlorides  \
# 0           7.91             0.74        0.73           11.10      0.446
# 1           6.71             0.68        0.70           12.20      0.454
# 2           7.41             0.71        0.92           13.60      0.460
# 3           7.81             0.79        0.68            7.50      0.451
# 4           8.51             0.53        0.79            0.90      0.444
# 5           7.01             0.61        0.79            7.90      0.462
# 6           7.71             0.67        0.77            5.20      0.450
# 7           7.31             0.73        0.58            7.60      0.452
# 8           8.91             0.59        0.71            1.10      0.438
# 9           7.61             0.68        0.69           15.20      0.456
# 10          7.11             0.71        0.86           10.60      0.442
# 11          7.11             0.64        0.72            2.10      0.456
# 12          9.01             0.75        0.77            1.40      0.455
# 13          7.81             0.61        0.84            7.80      0.455
# 14          7.11             0.68        0.67            2.30      0.453
# 15          7.51             0.65        0.82           17.80      0.456
# 16          7.11             0.66        0.75           12.85      0.458
# 17          7.21             0.78        0.92           11.80      0.454
# 18          6.91             0.76        0.79            7.40      0.446
# 19          8.71             0.69        0.68           17.50      0.455
#
#     freeSulfurDioxide  totalSulfurDioxide  density    pH  sulphates  alcohol  \
# 0               25.41              119.41  1.40620  3.15       0.75    10.91
# 1               59.41              196.41  1.40782  3.14       0.81     9.21
# 2               40.41              168.41  1.40760  3.07       0.93    10.01
# 3               24.41              160.41  1.40535  3.17       0.84    10.41
# 4               36.41               86.41  1.40026  2.80       0.96    12.41
# 5               30.41              145.41  1.40470  3.32       0.97    11.41
# 6               31.41              141.41  1.40310  3.16       1.00    11.41
# 7               69.41              219.41  1.40590  3.13       0.81     9.31
# 8               34.41               95.41  1.40272  2.83       0.77    10.41
# 9                6.41               41.41  1.40665  3.17       0.80    11.31
# 10              56.41              212.41  1.40700  3.22       1.00     9.91
# 11              30.41               96.41  1.40260  3.33       1.05    11.11
# 12              11.41              119.41  1.40556  3.17       0.88     9.81
# 13              27.41              153.41  1.40640  3.19       0.96     9.41
# 14              61.41              181.41  1.40394  3.45       1.04    11.01
# 15              39.41              145.41  1.40980  3.32       0.80     9.11
# 16              30.41              161.41  1.40860  3.44       0.88     9.91
# 17              62.41              163.41  1.40760  3.19       0.85     9.21
# 18              20.41              196.41  1.40712  3.47       0.89     9.51
# 19              48.41              253.41  1.41014  3.02       0.97     9.51
#
#     quality  rtSulfurDioxide
# 0       6.0         5.000000
# 1       6.0         7.681146
# 2       7.0         6.324555
# 3       5.0         4.898979
# 4       6.0         6.000000
# 5       7.0         5.477226
# 6       6.0         5.567764
# 7       5.0         8.306624
# 8       4.0         5.830952
# 9       6.0         2.449490
# 10      6.0         7.483315
# 11      8.0         5.477226
# 12      4.0         3.316625
# 13      7.0         5.196152
# 14      6.0         7.810250
# 15      5.0         6.244998
# 16      6.0         5.477226
# 17      5.0         7.874008
# 18      6.0         4.472136
# 19      6.0         6.928203

# %%
plt.figure(figsize=[10,6])
# plot bar graph
plt.bar(df1['quality'],df1['alcohol'],color='red')
# label x-axis
plt.xlabel('quality')
#label y-axis
plt.ylabel('alcohol')
# Out:
# Text(0, 0.5, 'alcohol')
