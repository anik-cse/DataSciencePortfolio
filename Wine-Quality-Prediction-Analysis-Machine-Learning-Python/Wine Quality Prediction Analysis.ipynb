# %%
# import pandas
import pandas as pd

# import numpy
import numpy as np

# import seaborn
import seaborn as sb

# Reading the dataset
import matplotlib.pyplot as plt

# Reading the dataset
df = pd.read_csv('D:\DataSciencePortfolio\Datasets\winedata.csv', sep=',')
import plotly.express as px

# Testing the datset
print(df.head())
print(df.info())
print(df.describe())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-37-f9c734e6d176> in <module>
#      13 # Reading the dataset
#      14 df = pd.read_csv('D:\DataSciencePortfolio\Datasets\winedata.csv', sep=',')
# ---> 15 import plotly.express as px
#      16
#      17 # Testing the datset
#
# ModuleNotFoundError: No module named 'plotly'

# %%
df1 = df

# %%
#cleaning columns name

df1.rename(columns={'fixed.acidity': 'fixedAcidity', 
                   'volatile.acidity':'volatileAcidity', 
                   'citric.acid': 'citricAcid',
                   'free.sulfur.dioxide': 'freeSulfurDioxide',
                  'total.sulfur.dioxide': 'totalSulfurDioxide',
                  'rt.sulfur.dioxide': 'rtSulfurDioxide'}, inplace=True)

# %%
display (df1)
# Out:
#       fixedAcidity  volatileAcidity  citricAcid  residual.sugar  chlorides  \
# 0              7.5             0.33        0.32            11.1      0.036
# 1              6.3             0.27        0.29            12.2      0.044
# 2              7.0             0.30        0.51            13.6      0.050
# 3              7.4             0.38        0.27             7.5      0.041
# 4              8.1             0.12        0.38             0.9      0.034
# ...            ...              ...         ...             ...        ...
# 2032           8.1             0.34        0.28             7.5      0.040
# 2033           7.4             0.19        0.31            14.5      0.045
# 2034           6.7             0.36        0.26             7.9      0.034
# 2035           7.7             0.28        0.35            15.3      0.056
# 2036           5.7             0.22        0.28             1.3      0.027
#
# ...

# %%
#adding two digits of ID as decimal points ID=20215041 for fixedAcidity
df1 = df1.assign(fixedAcidity=df1.fixedAcidity+0.41)

display (df1)
# Out:
#       fixedAcidity  volatileAcidity  citricAcid  residual.sugar  chlorides  \
# 0             7.91             0.33        0.32            11.1      0.036
# 1             6.71             0.27        0.29            12.2      0.044
# 2             7.41             0.30        0.51            13.6      0.050
# 3             7.81             0.38        0.27             7.5      0.041
# 4             8.51             0.12        0.38             0.9      0.034
# ...            ...              ...         ...             ...        ...
# 2032          8.51             0.34        0.28             7.5      0.040
# 2033          7.81             0.19        0.31            14.5      0.045
# 2034          7.11             0.36        0.26             7.9      0.034
# 2035          8.11             0.28        0.35            15.3      0.056
# 2036          6.11             0.22        0.28             1.3      0.027
#
# ...

# %%
#adding two digits of ID as decimal points ID=20215041

df1 = df1.assign(volatileAcidity=df1.volatileAcidity + 0.41)
df1 = df1.assign(citricAcid=df1.citricAcid + 0.41)
df1 = df1.assign(chlorides=df1.chlorides + 0.41)
df1 = df1.assign(freeSulfurDioxide=df1.freeSulfurDioxide + 0.41)
df1 = df1.assign(totalSulfurDioxide=df1.totalSulfurDioxide + 0.41)
df1 = df1.assign(density=df1.density + 0.41)
df1 = df1.assign(sulphates=df1.sulphates + 0.41)
df1 = df1.assign(alcohol=df1.alcohol + 0.41)

display (df1)
# Out:
#       fixedAcidity  volatileAcidity  citricAcid  residual.sugar  chlorides  \
# 0             7.91             1.15        1.14            11.1      0.856
# 1             6.71             1.09        1.11            12.2      0.864
# 2             7.41             1.12        1.33            13.6      0.870
# 3             7.81             1.20        1.09             7.5      0.861
# 4             8.51             0.94        1.20             0.9      0.854
# ...            ...              ...         ...             ...        ...
# 2032          8.51             1.16        1.10             7.5      0.860
# 2033          7.81             1.01        1.13            14.5      0.865
# 2034          7.11             1.18        1.08             7.9      0.854
# 2035          8.11             1.10        1.17            15.3      0.876
# 2036          6.11             1.04        1.10             1.3      0.847
#
# ...

# %%
details = df1

#finding missing values using isnull() function
# Count total NaN at each column in DataFrame

print(" \nCount total NaN at each column in a DataFrame : \n\n",
      details.isnull().sum())
# Out:
#
# Count total NaN at each column in a DataFrame :
#
#  fixedAcidity          0
# volatileAcidity       0
# citricAcid            0
# residual.sugar        0
# chlorides             0
# freeSulfurDioxide     0
# totalSulfurDioxide    0
# density               0
# pH                    0
# sulphates             0
# alcohol               0
# quality               0
# rtSulfurDioxide       0
# dtype: int64

# %%
# List of data series
datarowsSeries = [pd.Series([0.069,10,2.3,0,0.53,6.5,65.2,4.01,1,290,15,395,4.9], index=df1.columns ), 
                  pd.Series([0.069,11,2.3,0,0.6,6.6,65.3,4.2,1,290,15,395,4.9], index=df1.columns ) ]

# Passing the list of data series to the append() to add multiple rows
df1 = df1.append(datarowsSeries , ignore_index=True)

# %%
display (df1)
# Out:
#       fixedAcidity  volatileAcidity  citricAcid  residual.sugar  chlorides  \
# 0            7.910             1.15        1.14            11.1      0.856
# 1            6.710             1.09        1.11            12.2      0.864
# 2            7.410             1.12        1.33            13.6      0.870
# 3            7.810             1.20        1.09             7.5      0.861
# 4            8.510             0.94        1.20             0.9      0.854
# ...            ...              ...         ...             ...        ...
# 2034         7.110             1.18        1.08             7.9      0.854
# 2035         8.110             1.10        1.17            15.3      0.876
# 2036         6.110             1.04        1.10             1.3      0.847
# 2037         0.069            10.00        2.30             0.0      0.530
# 2038         0.069            11.00        2.30             0.0      0.600
#
# ...

# %%
# removing extra values

df1 = df1.drop(index=[2039,2038])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-e3cd3de781ff> in <module>
# ----> 1 df1 = df1.drop(index=[2039,2038])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
display (df1)
# Out:
#       fixedAcidity  volatileAcidity  citricAcid  residual.sugar  chlorides  \
# 0            7.910             1.15        1.14            11.1      0.856
# 1            6.710             1.09        1.11            12.2      0.864
# 2            7.410             1.12        1.33            13.6      0.870
# 3            7.810             1.20        1.09             7.5      0.861
# 4            8.510             0.94        1.20             0.9      0.854
# ...            ...              ...         ...             ...        ...
# 2034         7.110             1.18        1.08             7.9      0.854
# 2035         8.110             1.10        1.17            15.3      0.876
# 2036         6.110             1.04        1.10             1.3      0.847
# 2037         0.069            10.00        2.30             0.0      0.530
# 2038         0.069            11.00        2.30             0.0      0.600
#
# ...

# %%
df1.hist(bins=25,figsize=(10,10))
# display histogram
plt.show()

# %%
# creating box plots

def plot_boxplot(df1, ft):
    df1.boxplot(column=[ft])
    plt.grid(False)
    plt.show()

# %%
# create box plots
fig, ax = plt.subplots(ncols=6, nrows=2, figsize=(20,10))
index = 0
ax = ax.flatten()

for col, value in df.items():
    if col != 'type':
        sb.boxplot(y=col, data=df1, ax=ax[index])
        index += 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-79805ad53056> in <module>
#       6 for col, value in df.items():
#       7     if col != 'type':
# ----> 8         sb.boxplot(y=col, data=df1, ax=ax[index])
#       9         index += 1
#
# IndexError: index 12 is out of bounds for axis 0 with size 12

# %%
# finding the outliers

def outliers(df, ft):
    Q1 = df1[ft].quantile(0.25)
    Q3 = df1[ft].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR 
    
    ls = df1.index[ (df1[ft] < lower_bound) | (df1[ft] > upper_bound)]
    return ls

# %%
index_list = []
for feature in ['fixedAcidity', 'volatileAcidity', 'citricAcid', 'chlorides', 'freeSulfurDioxide', 'totalSulfurDioxide', 'density', 'sulphates', 'alcohol']:
    index_list.extend(outliers(df1,feature))

# %%
index_list
# Out:
# [1051,
#  1838,
#  2037,
#  2038,
#  99,
#  237,
#  456,
#  491,
#  499,
#  742,
#  845,
#  860,
#  1029,
#  1122,
#  1378,
#  1380,
#  1696,
#  1710,
#  1852,
#  1864,
#  1877,
#  2037,
#  2038,
#  82,
#  131,
#  135,
#  194,
#  222,
#  237,
#  239,
#  247,
#  257,
#  266,
#  294,
#  356,
#  376,
#  404,
#  426,
#  445,
#  602,
#  676,
#  698,
#  717,
#  865,
#  1011,
#  1029,
#  1076,
#  1094,
#  1114,
#  1242,
#  1260,
#  1262,
#  1263,
#  1277,
#  1288,
#  1310,
#  1346,
#  1368,
#  1370,
#  1371,
#  1395,
#  1463,
#  1470,
#  1517,
#  1544,
#  1571,
#  1596,
#  1623,
#  1666,
#  1708,
#  1800,
#  1813,
#  1826,
#  1867,
#  1933,
#  2016,
#  2037,
#  2038,
#  117,
#  542,
#  2037,
#  2038,
#  1618,
#  1931,
#  2037,
#  2038,
#  70,
#  157,
#  241,
#  420,
#  741,
#  824,
#  860,
#  947,
#  1152,
#  1230,
#  1266,
#  1292,
#  1298,
#  1337,
#  1350,
#  1471,
#  1521,
#  1549,
#  1651,
#  1748,
#  1818,
#  1875,
#  1889,
#  1943,
#  2037,
#  2038]

# %%
def remove(df1, ls):
    ls = sorted(set(ls))
    df1 = df1.drop(ls)
    return df1
df_cleaned = remove(df1, index_list)

# %%
df_cleaned.shape
# Out:
# (1940, 13)

# %%
print(df1.head(20))
# Out:
#     fixedAcidity  volatileAcidity  citricAcid  residual.sugar  chlorides  \
# 0           7.91             1.15        1.14           11.10      0.856
# 1           6.71             1.09        1.11           12.20      0.864
# 2           7.41             1.12        1.33           13.60      0.870
# 3           7.81             1.20        1.09            7.50      0.861
# 4           8.51             0.94        1.20            0.90      0.854
# 5           7.01             1.02        1.20            7.90      0.872
# 6           7.71             1.08        1.18            5.20      0.860
# 7           7.31             1.14        0.99            7.60      0.862
# 8           8.91             1.00        1.12            1.10      0.848
# 9           7.61             1.09        1.10           15.20      0.866
# 10          7.11             1.12        1.27           10.60      0.852
# 11          7.11             1.05        1.13            2.10      0.866
# ...

# %%
plot_boxplot(df_cleaned, 'alcohol')
plot_boxplot(df_cleaned, 'volatileAcidity')

# %%
plt.figure(figsize=[10,6])
# plot bar graph
plt.bar(df1['quality'],df1['alcohol'],color='red')
# label x-axis
plt.xlabel('quality')
#label y-axis
plt.ylabel('alcohol')
# Out:
# Text(0, 0.5, 'alcohol')

# %%
# ploting heatmap
plt.figure(figsize=[19,10],facecolor='blue')
sb.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
fig = px.histogram(df1,x='quality')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-133f3107d504> in <module>
# ----> 1 fig = px.histogram(df1,x='quality')
#       2 fig.show()
#
# NameError: name 'px' is not defined
