# %% [markdown]
# # Wine Quality Data Set:
# This is one of the most popular datasets along data science beginners. It is divided into 2 datasets.
# There are 4898 rows and 12 columns in this dataset. Read the data from
# https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/.
# For details: https://archive.ics.uci.edu/ml/datasets/wine
#
# Append the following five rows with your data frame.
# FixAcidity volaAcidity CitAcid ResiSugar chlo   Frsuldiox Totlsuldiox density pH  sulphates alcohol quality
# 7.8+.X     .88+.X      0.00+.X   1.9    0.09+.X  25.0+.X   67.0+.X    .991+.X 3.22 0.68+.X   9.8+.X    5
# 7.2+.X     .83+.X      0.01+.X   2.2    0.19+.X  15.0+.X   60.0+.X    .996+.X 3.52 0.55+.X   9.6+.X    6
# 7.9+.X     .89+.X      0.01+.X   1.7    0.08+.X  22.0+.X   57.0+.X    .997+.X 3.26 0.64+.X   9.8+.X    2
# 7.7+.X     .86+.X      0.02+.X   2.3    0.07+.X  11.0+.X   38.0+.X    .994+.X 3.12 0.08+.X   9.4+.X    3
# .X is the two last digits of your ID with a decimal point
# Hints: If your DataFrame is df, then use the following codes to append the first two rows with your
# dataframe.
#
#
# # List of data series
# datarowsSeries = [pd.Series([0.069,10,2.3,0,0.53,6.5,65.2,4.01,1,290,15,395,4.9,24],
#
# index=df.columns ), pd.Series([0.069,11,2.3,0,0.6,6.6,65.3,4.2,1,290,15,395,4.9,24],
# index=df.columns ) ]
#
# # Pass the list of data series to the append() to add multiple rows
# new_data = df.append(datarowsSeries , ignore_index=True)
# The wine in a scale that ranges from 0 (very bad) to 10 (excellent). Now, you need to reallocate the
# quality of wine as 0: 0 to 5 (Average quality) and 1: 6 to 10 (Good quality). Use the following codes
# to do so
# Hints:
#
# df['quality'] = df['quality'].where(df['quality']<= 5, 0)
# df['quality'] = df['quality'].where(df['quality']>5, 1)
# df['quality'] = df['quality'].map({0:'Average', 1:'Good'})
#
#
#
# 1. A description of the data: what it is and where it came from.
# 2. What questions /objectives you are addressing.
# 3. Data Cleaning, if required.
# 4. Construct suitable plots of the data.
# 5. Find the correlation between the quality of wine with other variables.
# 6. Conduct appropriate mean and proportion tests.
# 7. Fit a suitable model to predict the quality of wine.
# 8. A brief discussion of the results.

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
import plotly.express as px

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-093132d0-8c3c-469d-8208-f843c1e79d05" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-093132d0-8c3c-469d-8208-f843c1e79d05">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving winedata.csv to winedata.csv

# %%
import io
  
df = pd.read_csv(io.BytesIO(uploaded['winedata.csv']))
print(df)
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  ...  sulphates  alcohol  quality
# 0               7.5              0.33         0.32  ...       0.34     10.5        6
# 1               6.3              0.27         0.29  ...       0.40      8.8        6
# 2               7.0              0.30         0.51  ...       0.52      9.6        7
# 3               7.4              0.38         0.27  ...       0.43     10.0        5
# 4               8.1              0.12         0.38  ...       0.55     12.0        6
# ...             ...               ...          ...  ...        ...      ...      ...
# 2032            8.1              0.34         0.28  ...       0.55      9.8        6
# 2033            7.4              0.19         0.31  ...       0.50      9.2        6
# 2034            6.7              0.36         0.26  ...       0.30     12.2        7
# 2035            7.7              0.28         0.35  ...       0.50      9.6        5
# ...

# %%
# Missing Values
print(df.isna().sum())
# Out:
# fixed.acidity           0
# volatile.acidity        0
# citric.acid             0
# residual.sugar          0
# chlorides               0
# free.sulfur.dioxide     0
# total.sulfur.dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df1 = df
X = .31
datarowsSeries = [pd.Series([7.8, .88, 0.00, 1.9, 0.09, 25.0, 67.0, .991, 3.22, 0.68, 9.8, 5], index = df1.columns),
                  pd.Series([7.8+X, .88+X, 0.00+X, 1.9, 0.09+X, 25.0+X, 67.0+X, .991+X, 3.22, 0.68+X, 9.8+X, 5], index = df1.columns ),
                  pd.Series([7.2+X, .83+X, 0.01+X, 2.2, 0.19+X, 15.0+X, 60.0+X, .996+X, 3.52, 0.55+X, 9.6+X, 6], index = df1.columns ),
                  pd.Series([7.9+X, .89+X, 0.01+X, 1.7, 0.08+X, 22.0+X, 57.0+X, .997+X, 3.26, 0.64+X, 9.8+X, 2], index = df1.columns ),
                  pd.Series([7.7+X, .86+X, 0.02+X, 2.3, 0.07+X, 11.0+X, 38.0+X, .994+X, 3.12, 0.08+X, 9.4+X, 3], index = df1.columns )]

new_data = df1.append(datarowsSeries, ignore_index= True)

new_data.tail()
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  ...  sulphates  alcohol  quality
# 2037           7.80              0.88         0.00  ...       0.68     9.80      5.0
# 2038           8.11              1.19         0.31  ...       0.99    10.11      5.0
# 2039           7.51              1.14         0.32  ...       0.86     9.91      6.0
# 2040           8.21              1.20         0.32  ...       0.95    10.11      2.0
# 2041           8.01              1.17         0.33  ...       0.39     9.71      3.0
#
# [5 rows x 12 columns]

# %%
new_data.describe()
# Out:
#        fixed.acidity  volatile.acidity  ...      alcohol      quality
# count    2042.000000       2042.000000  ...  2042.000000  2042.000000
# mean        6.828325          0.268648  ...    10.597129     5.925563
# std         0.754451          0.087594  ...     1.221818     0.852321
# min         4.400000          0.080000  ...     8.400000     2.000000
# 25%         6.300000          0.210000  ...     9.500000     5.000000
# 50%         6.800000          0.260000  ...    10.500000     6.000000
# 75%         7.300000          0.315000  ...    11.425000     6.000000
# max         8.800000          1.200000  ...    14.200000     9.000000
#
# [8 rows x 12 columns]

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2042 entries, 0 to 2041
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed.acidity         2042 non-null   float64
#  1   volatile.acidity      2042 non-null   float64
#  2   citric.acid           2042 non-null   float64
#  3   residual.sugar        2042 non-null   float64
#  4   chlorides             2042 non-null   float64
#  5   free.sulfur.dioxide   2042 non-null   float64
#  6   total.sulfur.dioxide  2042 non-null   float64
#  7   density               2042 non-null   float64
#  8   pH                    2042 non-null   float64
#  9   sulphates             2042 non-null   float64
#  10  alcohol               2042 non-null   float64
#  11  quality               2042 non-null   float64
# dtypes: float64(12)
# memory usage: 191.6 KB

# %%
import matplotlib.pyplot as plt

new_data.hist(bins=25,figsize=(20,20))
# display histogram
plt.show()

# %%
for column in new_data:
    plt.figure(figsize=(20,5))
    new_data.boxplot([column])

# %%
# finding the outliers

def outliers(new_data, ft):
    Q1 = new_data[ft].quantile(0.25)
    Q3 = new_data[ft].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR 
    
    ls = new_data.index[ (new_data[ft] < lower_bound) | (new_data[ft] > upper_bound)]
    return ls

# %%
new_data.rename(columns = {'fixed.acidity':'fixedacidity', 'volatile.acidity':'volatileacidity','citric.acid':'citricacid','residual.sugar':'residualsugar',
                      'chlorides':'chlorides','free.sulfur.dioxide':'freesulfurdioxide','total.sulfur.dioxide':'totalsulfurdioxide','density':'density',
                      'pH':'pH','alcohol':'alcohol','quality':'quality'}, inplace = True)

new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2042 entries, 0 to 2041
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   fixedacidity        2042 non-null   float64
#  1   volatileacidity     2042 non-null   float64
#  2   citricacid          2042 non-null   float64
#  3   residualsugar       2042 non-null   float64
#  4   chlorides           2042 non-null   float64
#  5   freesulfurdioxide   2042 non-null   float64
#  6   totalsulfurdioxide  2042 non-null   float64
#  7   density             2042 non-null   float64
#  8   pH                  2042 non-null   float64
#  9   sulphates           2042 non-null   float64
#  10  alcohol             2042 non-null   float64
#  11  quality             2042 non-null   float64
# dtypes: float64(12)
# memory usage: 191.6 KB

# %%
#index_list = []
#for feature in ['fixedacidity', 'volatileacidity','citricacid', 'residualsugar', 'chlorides', 'freesulfurdioxide', 'totalsulfurdioxide', 'density', 'pH','alcohol']:
#    index_list.extend(outliers(new_data,feature))

#index_list

# %%
#def remove(new_data, ls):
#    ls = sorted(set(ls))
#    new_data = new_data.drop(ls)
#    return new_data
#df_cleaned = remove(new_data, index_list)
#
#df_cleaned.shape

# %%
#for column in new_data:
#    plt.figure(figsize=(20,5))
#    df_cleaned.boxplot([column])

# %%
#plt.figure(figsize=[7,6])
## plot bar graph
#plt.bar(df_cleaned['quality'],df_cleaned['fixedacidity'],color='red')
## label x-axis
#plt.xlabel('quality')
##label y-axis
#plt.ylabel('fixed.acidity')
#
#
#plt.figure(figsize=[7,6])
## plot bar graph
#plt.bar(df_cleaned['quality'],df_cleaned['volatileacidity'],color='red')
## label x-axis
#plt.xlabel('quality')
##label y-axis
#plt.ylabel('volatile.acidity')
#
#
#plt.figure(figsize=[7,6])
## plot bar graph
#plt.bar(df_cleaned['quality'],df_cleaned['citricacid'],color='red')
## label x-axis
#plt.xlabel('quality')
##label y-axis
#plt.ylabel('citric.acid')
#
#
#plt.figure(figsize=[7,6])
## plot bar graph
#plt.bar(df_cleaned['quality'],df_cleaned['residualsugar'],color='red')
## label x-axis
#plt.xlabel('quality')
##label y-axis
#plt.ylabel('residual.sugar')
#
#
#plt.figure(figsize=[7,6])
## plot bar graph
#plt.bar(df_cleaned['quality'],df_cleaned['chlorides'],color='red')
## label x-axis
#plt.xlabel('quality')
##label y-axis
#plt.ylabel('chlorides')
#
#
#plt.figure(figsize=[7,6])
## plot bar graph
#plt.bar(df_cleaned['quality'],df_cleaned['freesulfurdioxide'],color='red')
## label x-axis
#plt.xlabel('quality')
##label y-axis
#plt.ylabel('free.sulfur.dioxide')
#
#
#plt.figure(figsize=[7,6])
## plot bar graph
#plt.bar(df_cleaned['quality'],df_cleaned['totalsulfurdioxide'],color='red')
## label x-axis
#plt.xlabel('quality')
##label y-axis
#plt.ylabel('total.sulfur.dioxide')
#
#
#plt.figure(figsize=[7,6])
## plot bar graph
#plt.bar(df_cleaned['quality'],df_cleaned['density'],color='red')
## label x-axis
#plt.xlabel('quality')
##label y-axis
#plt.ylabel('density')
#
#
#plt.figure(figsize=[7,6])
## plot bar graph
#plt.bar(df_cleaned['quality'],df_cleaned['pH'],color='red')
## label x-axis
#plt.xlabel('quality')
##label y-axis
#plt.ylabel('pH')
#
#
#plt.figure(figsize=[7,6])
## plot bar graph
#plt.bar(df_cleaned['quality'],df_cleaned['sulphates'],color='red')
## label x-axis
#plt.xlabel('quality')
##label y-axis
#plt.ylabel('sulphates')
#
#
#plt.figure(figsize=[7,6])
## plot bar graph
#plt.bar(df_cleaned['quality'],df_cleaned['alcohol'],color='red')
## label x-axis
#plt.xlabel('quality')
##label y-axis
#plt.ylabel('alcohol')

# %%
# ploting heatmap
import seaborn as sb
new_data[['fixedacidity','volatileacidity','citricacid','residualsugar','chlorides','quality']].corr()
# Out:
#                  fixedacidity  volatileacidity  ...  chlorides   quality
# fixedacidity         1.000000        -0.028170  ...   0.097881 -0.060708
# volatileacidity     -0.028170         1.000000  ...   0.393485 -0.155932
# citricacid           0.245445        -0.134585  ...   0.009272  0.030657
# residualsugar        0.055589         0.045065  ...   0.099632 -0.126809
# chlorides            0.097881         0.393485  ...   1.000000 -0.231232
# quality             -0.060708        -0.155932  ...  -0.231232  1.000000
#
# [6 rows x 6 columns]

# %%
plt.figure(figsize=[19,10],facecolor='white')
sb.heatmap(new_data[['fixedacidity','volatileacidity','citricacid','residualsugar','chlorides','quality']].corr(),annot=True)

# %%
# ploting heatmap
import seaborn as sb
new_data[['freesulfurdioxide','totalsulfurdioxide','density','pH','alcohol','quality']].corr()
# Out:
#                     freesulfurdioxide  totalsulfurdioxide  ...   alcohol   quality
# freesulfurdioxide            1.000000            0.638626  ... -0.267122 -0.007659
# totalsulfurdioxide           0.638626            1.000000  ... -0.477617 -0.170347
# density                      0.023662            0.028737  ... -0.188596 -0.163110
# pH                          -0.022266           -0.012474  ...  0.114193  0.093076
# alcohol                     -0.267122           -0.477617  ...  1.000000  0.439515
# quality                     -0.007659           -0.170347  ...  0.439515  1.000000
#
# [6 rows x 6 columns]

# %%
plt.figure(figsize=[19,10],facecolor='white')
sb.heatmap(new_data[['freesulfurdioxide','totalsulfurdioxide','density','pH','alcohol','quality']].corr(),annot=True)

# %%
# ploting heatmap
import seaborn as sb

plt.figure(figsize=[19,10],facecolor='white')
sb.heatmap(new_data.corr(),annot=True)

# %%
fixedacidityMean = new_data['fixedacidity'].mean()
volatileacidityMean = new_data['volatileacidity'].mean()
citricacidMean = new_data['citricacid'].mean()
residualsugarMean = new_data['residualsugar'].mean()
chloridesMean = new_data['chlorides'].mean()
freesulfurdioxideMean = new_data['freesulfurdioxide'].mean()
totalsulfurdioxideMean = new_data['totalsulfurdioxide'].mean()
densityMean = new_data['density'].mean()
pHMean = new_data['pH'].mean()
alcoholMean = new_data['alcohol'].mean()
qualityMean = new_data['quality'].mean()

# %%
from statsmodels.stats import weightstats as stests
#'fixedacidity','volatileacidity','citricacid','residualsugar','chlorides','quality'#'freesulfurdioxide','totalsulfurdioxide','density','pH','alcohol','quality'

ztest ,pval = stests.ztest(new_data['fixedacidity'], x2=None, value=fixedacidityMean)
print(pval)
print('p-value of mean Test =',pval)
# Out:
# 0.9999999999998727
# p-value of mean Test = 0.9999999999998727

# %%
ztest ,pval = stests.ztest(new_data['volatileacidity'], x2=None, value=volatileacidityMean)
print(pval)
print('p-value of mean Test =',pval)
# Out:
# 0.9999999999997944
# p-value of mean Test = 0.9999999999997944

# %%
ztest ,pval = stests.ztest(new_data['citricacid'], x2=None, value=citricacidMean)
print(pval)
print('p-value of mean Test =',pval)
# Out:
# 0.9999999999999577
# p-value of mean Test = 0.9999999999999577

# %%
ztest ,pval = stests.ztest(new_data['residualsugar'], x2=None, value=residualsugarMean)
print(pval)
print('p-value of mean Test =',pval)
# Out:
# 2.542882428861804e-263
# p-value of mean Test = 2.542882428861804e-263

# %%
ztest ,pval = stests.ztest(new_data['chlorides'], x2=None, value=chloridesMean)
print(pval)
print('p-value of mean Test =',pval)
# Out:
# 0.9999999999996665
# p-value of mean Test = 0.9999999999996665

# %%
#'freesulfurdioxide','totalsulfurdioxide','density','pH','alcohol','quality'
ztest ,pval = stests.ztest(new_data['freesulfurdioxide'], x2=None, value=freesulfurdioxideMean)
print(pval)
print('p-value of mean Test =',pval)
# Out:
# 1.0
# p-value of mean Test = 1.0

# %%
#'freesulfurdioxide','totalsulfurdioxide','density','pH','alcohol','quality'
ztest ,pval = stests.ztest(new_data['totalsulfurdioxide'], x2=None, value=totalsulfurdioxideMean)
print(pval)
print('p-value of mean Test =',pval)
# Out:
# 1.0
# p-value of mean Test = 1.0

# %%
ztest ,pval = stests.ztest(new_data['density'], x2=None, value=densityMean)
print(pval)
print('p-value of mean Test =',pval)
# Out:
# 0.9999999999991444
# p-value of mean Test = 0.9999999999991444

# %%
ztest ,pval = stests.ztest(new_data['pH'], x2=None, value=pHMean)
print(pval)
print('p-value of mean Test =',pval)
# Out:
# 0.9999999999979228
# p-value of mean Test = 0.9999999999979228

# %%
ztest ,pval = stests.ztest(new_data['alcohol'], x2=None, value=alcoholMean)
print(pval)
print('p-value of mean Test =',pval)
# Out:
# 0.9999999999994758
# p-value of mean Test = 0.9999999999994758

# %%
ztest ,pval = stests.ztest(new_data['quality'], x2=None, value=qualityMean)
print(pval)
print('p-value of mean Test =',pval)
# Out:
# 1.0
# p-value of mean Test = 1.0

# %%
from statsmodels.stats.proportion import proportions_ztest

count = new_data.fixedacidity.value_counts()
print(count)
nobs = len(new_data.fixedacidity)
print(nobs)

value = .5

####stat, pval = proportions_ztest(count, nobs, value, alternative='two-sided')
####stat, pval = proportions_ztest(count, nobs, value, alternative='larger')

stat, pval = proportions_ztest(count, nobs, value, alternative='two-sided')

print('z calculated value:', stat)

print('p-value for proportion test',pval)

##plt.boxplot(new_data.LSTAT)

##plt.show()
# Out:
# 6.80    128
# 7.00    120
# 6.60    120
# 6.40    106
# 7.40    102
# 6.50    102
# 6.90    101
# 6.70    100
# 6.20     88
# 7.10     85
# 7.20     79
# 6.00     79
# 7.60     69
# 7.30     68
# 6.30     67
# 6.10     63
# 5.90     49
# 5.80     47
# 7.50     47
# 7.80     43
# 7.70     42
# 8.00     38
# 5.70     32
# 5.60     32
# 7.90     28
# 8.20     27
# 8.10     24
# 8.30     21
# 8.50     16
# 8.60     14
# 8.40     14
# 5.50     14
# 5.00     12
# 5.30     11
# 5.10      9
# 5.20      9
# 8.80      8
# 8.70      6
# 5.40      6
# 4.80      5
# 4.90      3
# 6.15      2
# 4.40      1
# 4.70      1
# 8.11      1
# 7.51      1
# 8.21      1
# 8.01      1
# Name: fixedacidity, dtype: int64
# 2042
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-73-1c9c0935b833> in <module>()
# ...

# %%
for a in range(len(df_cleaned.corr().columns)):
    for b in range(a):
        if abs(df_cleaned.corr().iloc[a,b]) >0.7:
            name = df_cleaned.corr().columns[a]
            print(name)
# Out:
# density
# alcohol

# %%
new_df=df_cleaned.drop('density',axis=1)
new_df=df_cleaned.drop('alcohol',axis=1)

# %%
new_df.isnull().sum()
# Out:
# fixedacidity          0
# volatileacidity       0
# citricacid            0
# residualsugar         0
# chlorides             0
# freesulfurdioxide     0
# totalsulfurdioxide    0
# density               0
# pH                    0
# sulphates             0
# quality               0
# dtype: int64

# %%
new_df.update(new_df.fillna(new_df.mean()))

# %%
# catogerical vars 
next_df = pd.get_dummies(new_df,drop_first=True)
# display new dataframe
next_df
# Out:
#       fixedacidity  volatileacidity  citricacid  ...    pH  sulphates  quality
# 0              7.5             0.33        0.32  ...  3.15       0.34      6.0
# 1              6.3             0.27        0.29  ...  3.14       0.40      6.0
# 2              7.0             0.30        0.51  ...  3.07       0.52      7.0
# 3              7.4             0.38        0.27  ...  3.17       0.43      5.0
# 5              6.6             0.20        0.38  ...  3.32       0.56      7.0
# ...            ...              ...         ...  ...   ...        ...      ...
# 2032           8.1             0.34        0.28  ...  3.14       0.55      6.0
# 2033           7.4             0.19        0.31  ...  3.10       0.50      6.0
# 2034           6.7             0.36        0.26  ...  2.99       0.30      7.0
# 2035           7.7             0.28        0.35  ...  3.27       0.50      5.0
# 2036           5.7             0.22        0.28  ...  3.35       0.38      7.0
#
# ...

# %%
sampledummies = new_df


for i in df.quality:
  print(":This is printing i",i)
  if i>=7:
    print("if",i)
    sampledummies['best quality'] = 1
    print (sampledummies['best quality'])

  else:
    print("else",i)
    sampledummies['best quality'] = 0
    print (sampledummies['best quality'])


print("Table")
print(sampledummies)



              


#sampledummies['best quality'] = bestQuality[x]
# Out:
# Streaming output truncated to the last 5000 lines.
# Name: best quality, Length: 1965, dtype: int64
# :This is printing i 6
# else 6
# 0       0
# 1       0
# 2       0
# 3       0
# 5       0
#        ..
# 2032    0
# 2033    0
# 2034    0
# 2035    0
# 2036    0
# Name: best quality, Length: 1965, dtype: int64
# :This is printing i 5
# else 5
# 0       0
# 1       0
# 2       0
# 3       0
# 5       0
#        ..
# 2032    0
# 2033    0
# 2034    0
# 2035    0
# 2036    0
# Name: best quality, Length: 1965, dtype: int64
# :This is printing i 7
# if 7
# 0       1
# 1       1
# 2       1
# 3       1
# 5       1
#        ..
# 2032    1
# 2033    1
# 2034    1
# 2035    1
# 2036    1
# Name: best quality, Length: 1965, dtype: int64
# :This is printing i 6
# else 6
# 0       0
# 1       0
# 2       0
# 3       0
# 5       0
#        ..
# 2032    0
# 2033    0
# 2034    0
# 2035    0
# 2036    0
# Name: best quality, Length: 1965, dtype: int64
# :This is printing i 7
# if 7
# 0       1
# ...

# %% [markdown]
# Splitting dataset
# Now we perform a split operation on our dataset:

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-524a8f3743d4> in <module>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=40)
#
# NameError: name 'x' is not defined

# %% [markdown]
# Normalization
# We do normalization on numerical data because our data is unbalanced it means the difference between the variable values is high so we convert them into 1 and 0.

# %%
#importing module
from sklearn.preprocessing import MinMaxScaler
# creating normalization object 
norm = MinMaxScaler()
# fit data
norm_fit = norm.fit(x_train)
new_xtrain = norm_fit.transform(x_train)
new_xtest = norm_fit.transform(x_test)
# display values
print(new_xtrain)

# %% [markdown]
# Applying Model
# This is the last step where we apply any suitable model which will give more accuracy, here we will use RandomForestClassifier because it was the only ML model that gives the 88% accuracy which was considered as the best accuracy.
#
# RandomForestClassifier:-

# %%
# importing modules
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
#creating RandomForestClassifier constructor
rnd = RandomForestClassifier()
# fit data
fit_rnd = rnd.fit(new_xtrain,y_train)
# predicting score
rnd_score = rnd.score(new_xtest,y_test)
print('score of model is : ',rnd_score)
# display error rate
print('calculating the error')
# calculating mean squared error
rnd_MSE = mean_squared_error(y_test,y_predict)
# calculating root mean squared error
rnd_RMSE = np.sqrt(MSE)
# display MSE
print('mean squared error is : ',rnd_MSE)
# display RMSE
print('root mean squared error is : ',rnd_RMSE)
print(classification_report(x_predict,y_test))

# %% [markdown]
# Now, we are at the end of our article, we can differentiate the predicted values and actual value.

# %%
x_predict = list(rnd.predict(x_test))
predicted_df = {'predicted_values': x_predict, 'original_values': y_test}
#creating new dataframe
pd.DataFrame(predicted_df).head(20)

# %% [markdown]
# Saving Model
# At last, we save our machine learning model

# %%
import pickle
file = 'wine_quality'
#save file
save = pickle.dump(rnd,open(file,'wb'))

# %% [markdown]
# So, at this step, our machine learning prediction is over.
#
# End Notes
# This is one of the interesting articles that I have written because it was on today’s current top technology machine learning, but I was used basic language to explain this article so, you can’t get difficulty on understanding.
#
# If you have any question regarding this article then your will feel free to ask in the comment section below.
#
# Thank you.
#
# The media shown in this article are not owned by Analytics Vidhya and is used at the Author’s discretion.
